# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def char_frequency(text):
    letras = {'a':0,'b':0,'c':0,'d':0,'e':0,'f':0,'g':0,'h':0,'i':0,'j':0,'k':0,'l':0,'m':0,'n':0,
              'ñ':0,'o':0,'p':0,'k':0,'r':0,'s':0,'t':0,'u':0,'v':0,'w':0,'x':0,'y':0,'z':0}
    for caracter in text:
        if caracter in letras.keys():
            letras[caracter] = letras[caracter] + 1
    return letras

# %%
texto =open("noticias.txt",'r',encoding="utf8").read().lower()
texto = texto.replace(' ','')
F= pd.DataFrame.from_dict(char_frequency(texto),orient='index',columns=['Frec'])
F.to_dict('dict')
F['Probabilidad'] = F['Frec']/F['Frec'].sum()*100
F.sort_values(by='Frec',ascending = False)
# Out:
#    Frec  Probabilidad
# e  1035     13.695911
# a   912     12.068281
# o   686      9.077676
# i   624      8.257245
# n   550      7.278020
# s   529      7.000132
# r   488      6.457589
# d   431      5.703321
# c   408      5.398968
# l   377      4.988752
# t   347      4.591769
# u   282      3.731640
# m   225      2.977372
# p   223      2.950906
# g    75      0.992457
# v    70      0.926294
# b    68      0.899828
# y    47      0.621940
# f    42      0.555776
# h    42      0.555776
# j    37      0.489612
# x    28      0.370517
# z    22      0.291121
# ñ     9      0.119095
# k     0      0.000000
# w     0      0.000000

# %%
F['Probabilidad'].plot(kind = 'bar')
F.to_csv (r'Frecuencias.csv')
